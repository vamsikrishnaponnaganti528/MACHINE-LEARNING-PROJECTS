# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\ponna\Downloads\weather_data.csv")
df
# Out:
#           DATE       CITy  TEMPERATURE  HUMIDITY_% CONDITION
# 0   01-01-1900  HYDERABAD           28          60     SUNNY
# 1   02-01-1990  HYDERABAD           29          52     SUNNY
# 2   03-01-1990  HYDERABAD           30          58    CLOUDY
# 3   04-01-1990  HYDERABAD           31          55    CLOUDY
# 4   05-01-1990  HYDERABAD           32          57    CLOUDY
# 5   06-01-1990  HYDERABAD           33          55     SUNNY
# 6   07-01-1990  BANGALORE           34          54     SUNNY
# 7   08-01-1990  BANGALORE           35          55     SUNNY
# 8   09-01-1990  BANGALORE           36          58     SUNNY
# 9   10-01-1990  BANGALORE           37          59     SUNNY
# 10  11-01-1990  BANGALORE           38          60    CLOUDY
# 11  12-01-1990  BANGALORE           39          61    CLOUDY

# %%
df.head(3)
# Out:
#          DATE       CITy  TEMPERATURE  HUMIDITY_% CONDITION
# 0  01-01-1900  HYDERABAD           28          60     SUNNY
# 1  02-01-1990  HYDERABAD           29          52     SUNNY
# 2  03-01-1990  HYDERABAD           30          58    CLOUDY

# %%
df.tail(3)
# Out:
#           DATE       CITy  TEMPERATURE  HUMIDITY_% CONDITION
# 9   10-01-1990  BANGALORE           37          59     SUNNY
# 10  11-01-1990  BANGALORE           38          60    CLOUDY
# 11  12-01-1990  BANGALORE           39          61    CLOUDY

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   DATE         12 non-null     object
#  1   CITy         12 non-null     object
#  2   TEMPERATURE  12 non-null     int64
#  3   HUMIDITY_%   12 non-null     int64
#  4   CONDITION    12 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 612.0+ bytes

# %%
df.shape
# Out:
# (12, 5)

# %%
df[2:4]
# Out:
#          DATE       CITy  TEMPERATURE  HUMIDITY_% CONDITION
# 2  03-01-1990  HYDERABAD           30          58    CLOUDY
# 3  04-01-1990  HYDERABAD           31          55    CLOUDY

# %%
df.columns
# Out:
# Index(['DATE', 'CITy', 'TEMPERATURE', 'HUMIDITY_%', 'CONDITION'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=12, step=1)

# %%
df.dtypes
# Out:
# DATE           object
# CITy           object
# TEMPERATURE     int64
# HUMIDITY_%      int64
# CONDITION      object
# dtype: object

# %%
df.DATE
# Out:
# 0     01-01-1900
# 1     02-01-1990
# 2     03-01-1990
# 3     04-01-1990
# 4     05-01-1990
# 5     06-01-1990
# 6     07-01-1990
# 7     08-01-1990
# 8     09-01-1990
# 9     10-01-1990
# 10    11-01-1990
# 11    12-01-1990
# Name: DATE, dtype: object

# %%
df[['DATE','CONDITION']]
# Out:
#           DATE CONDITION
# 0   01-01-1900     SUNNY
# 1   02-01-1990     SUNNY
# 2   03-01-1990    CLOUDY
# 3   04-01-1990    CLOUDY
# 4   05-01-1990    CLOUDY
# 5   06-01-1990     SUNNY
# 6   07-01-1990     SUNNY
# 7   08-01-1990     SUNNY
# 8   09-01-1990     SUNNY
# 9   10-01-1990     SUNNY
# 10  11-01-1990    CLOUDY
# 11  12-01-1990    CLOUDY

# %%
df['DATE'][df['CONDITION']=='CLOUDY']
# Out:
# 2     03-01-1990
# 3     04-01-1990
# 4     05-01-1990
# 10    11-01-1990
# 11    12-01-1990
# Name: DATE, dtype: object

# %% [markdown]
# # Reading Data

# %%
df = pd.DataFrame({
    "Name" : ["Vamsi","Raju","Madhu"],
    "Age" : [21,25,21]
})
df
# Out:
#     Name  Age
# 0  Vamsi   21
# 1   Raju   25
# 2  Madhu   21

# %%
df.head(2)
# Out:
#     Name  Age
# 0  Vamsi   21
# 1   Raju   25

# %%
df.tail(1)
# Out:
#     Name  Age
# 2  Madhu   21

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    3 non-null      object
#  1   Age     3 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 180.0+ bytes

# %%
df.shape
# Out:
# (3, 2)

# %%
df[1:2]
# Out:
#    Name  Age
# 1  Raju   25

# %%
df.columns
# Out:
# Index(['Name', 'Age'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df.dtypes
# Out:
# Name    object
# Age      int64
# dtype: object

# %%
df.Name
# Out:
# 0    Vamsi
# 1     Raju
# 2    Madhu
# Name: Name, dtype: object

# %%
df[['Name','Age']]
# Out:
#     Name  Age
# 0  Vamsi   21
# 1   Raju   25
# 2  Madhu   21
