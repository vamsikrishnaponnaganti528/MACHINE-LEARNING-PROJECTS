# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\ponna\OneDrive\Desktop\Book1.csv")
df
# Out:
#         city  humidity  temp
# 0        Hyd      34.0  56.0
# 1        kkd      45.0  67.0
# 2        vzg      56.0   NaN
# 3        Hyd      23.0  32.0
# 4        vzg      34.0  89.0
# 5        kkd       NaN  67.0
# 6  bangalore      78.0  67.0

# %%
df.min()
# Out:
# city         Hyd
# humidity    23.0
# temp        32.0
# dtype: object

# %%
df.max()
# Out:
# city         vzg
# humidity    78.0
# temp        89.0
# dtype: object

# %%
df.columns
# Out:
# Index(['city', 'humidity', 'temp'], dtype='object')

# %%
df.head()
# Out:
#   city  humidity  temp
# 0  Hyd      34.0  56.0
# 1  kkd      45.0  67.0
# 2  vzg      56.0   NaN
# 3  Hyd      23.0  32.0
# 4  vzg      34.0  89.0

# %%
df.tail()
# Out:
#         city  humidity  temp
# 2        vzg      56.0   NaN
# 3        Hyd      23.0  32.0
# 4        vzg      34.0  89.0
# 5        kkd       NaN  67.0
# 6  bangalore      78.0  67.0

# %%
df['humidity'].mean()
# Out:
# 45.0

# %%
df['humidity'].mode()
# Out:
# 0    34.0
# Name: humidity, dtype: float64

# %%
df['humidity'].median()
# Out:
# 39.5

# %%
df['humidity'].std()
# Out:
# 19.677398201998148

# %%
df['humidity'].var()
# Out:
# 387.2
